# %%
! pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 217.9 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.8 kB 281.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 323.9 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/44.5 MB 1.3 MB/s eta 0:00:34
#    ---------------------------------------- 0.2/44.5 MB 2.1 MB/s eta 0:00:22
#    ---------------------------------------- 0.3/44.5 MB 2.5 MB/s eta 0:00:18
#    ---------------------------------------- 0.4/44.5 MB 2.3 MB/s eta 0:00:20
#    ---------------------------------------- 0.5/44.5 MB 2.4 MB/s eta 0:00:18
#     --------------------------------------- 0.7/44.5 MB 2.7 MB/s eta 0:00:16
# ...

# %%
from scipy import constants

# %%
print(constants.pi) # Value of π
print(constants.g) # Acceleration due to gravity
print(constants.c) # Speed of light in vacuum
# Out:
# 3.141592653589793
# 9.80665
# 299792458.0
